# %%
import os
os.chdir('D:\\Study\\RMIT\\2022\\COSC2793 - Computational Machine Learning\\Assignment02\\CML-Assign2')
os.getcwd()
# Out:
# 'D:\\Study\\RMIT\\2022\\COSC2793 - Computational Machine Learning\\Assignment02\\CML-Assign2'

# %%
from final_simulation._env.real_intersection import RealIntersection8, RealIntersection9, RealIntersection10, RealIntersection11
from final_simulation._sumo.simplest_intersection_simulation import SignalStates, SumoSimulation
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from final_simulation._env.callbacks import SaveOnBestTrainingRewardCallback
import os
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Reward 08

# %%
log_dir = "final_simulation\\_models\\reward_07\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 90
number_episodes = 500

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection8(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.01)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))

# %% [markdown]
# ## Reward 10

# %%
log_dir = "final_simulation\\_models\\reward_10\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 90
number_episodes = 1000

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection10(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.001)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))

# %% [markdown]
# ## Reward 11

# %%
log_dir = "final_simulation\\_models\\reward_11\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 180
number_episodes = 500

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection11(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.001)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -6.55e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 100       |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.56     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 99        |
# |    policy_loss        | -5.83e+03 |
# |    value_loss         | 1.7e+07   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1e+05    |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 200       |
# |    time_elapsed       | 204       |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.79     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 199       |
# |    policy_loss        | -3.24e+03 |
# |    value_loss         | 4.8e+06   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.15e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 300       |
# |    time_elapsed       | 320       |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.96     |
# |    explained_variance | 4.2e-05   |
# |    learning_rate      | 0.001     |
# |    n_updates          | 299       |
# |    policy_loss        | -694      |
# |    value_loss         | 1.03e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 1800
# Best mean reward: -inf - Last mean reward per episode: -126158.00
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.27e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 400       |
# |    time_elapsed       | 472       |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.96     |
# |    explained_variance | 2.32e-06  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 399       |
# |    policy_loss        | -330      |
# |    value_loss         | 2.52e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.33e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 500       |
# |    time_elapsed       | 598       |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.86     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 499       |
# |    policy_loss        | -1.03e+04 |
# |    value_loss         | 3.67e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.24e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 600       |
# |    time_elapsed       | 703       |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.98     |
# |    explained_variance | 2.21e-06  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 599       |
# |    policy_loss        | -1.98e+03 |
# |    value_loss         | 1.5e+06   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.12e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 700       |
# |    time_elapsed       | 804       |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.89     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 699       |
# |    policy_loss        | -1.68e+03 |
# |    value_loss         | 6.03e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 3600
# Best mean reward: -126158.00 - Last mean reward per episode: -108421.60
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.01e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 800       |
# |    time_elapsed       | 901       |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -1.98     |
# |    explained_variance | 3.82e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 799       |
# |    policy_loss        | -1.35e+03 |
# |    value_loss         | 6.11e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.32e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 900       |
# |    time_elapsed       | 997       |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.75     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 899       |
# |    policy_loss        | -225      |
# |    value_loss         | 9.59e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.91e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1000      |
# |    time_elapsed       | 1099      |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.58     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -3.39e+03 |
# |    value_loss         | 2.95e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 5400
# Best mean reward: -108421.60 - Last mean reward per episode: -84515.40
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.45e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1100      |
# |    time_elapsed       | 1196      |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -1.93     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1099      |
# |    policy_loss        | -2.57e+03 |
# |    value_loss         | 2.29e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.19e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1200      |
# |    time_elapsed       | 1295      |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.962    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1199      |
# |    policy_loss        | -1.56e+03 |
# |    value_loss         | 3.55e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.73e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1300      |
# |    time_elapsed       | 1419      |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.899    |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1299      |
# |    policy_loss        | -258      |
# |    value_loss         | 1.34e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.89e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1400      |
# |    time_elapsed       | 1537      |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.363    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.212     |
# |    value_loss         | 11.1      |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 7200
# Best mean reward: -84515.40 - Last mean reward per episode: -88635.27
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.82e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1500      |
# |    time_elapsed       | 1647      |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.92     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1499      |
# |    policy_loss        | -9.78e+03 |
# |    value_loss         | 4.85e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.04e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1600      |
# |    time_elapsed       | 1757      |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1599      |
# |    policy_loss        | -3.54e+03 |
# |    value_loss         | 3.27e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.98e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1700      |
# |    time_elapsed       | 1867      |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1699      |
# |    policy_loss        | -890      |
# |    value_loss         | 3.65e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 9000
# Best mean reward: -84515.40 - Last mean reward per episode: -94451.82
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.45e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1800      |
# |    time_elapsed       | 1976      |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.87     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1799      |
# |    policy_loss        | -1e+03    |
# |    value_loss         | 2.77e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.37e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1900      |
# |    time_elapsed       | 2087      |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.278    |
# |    explained_variance | 3.12e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.201     |
# |    value_loss         | 17.9      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.71e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2000      |
# |    time_elapsed       | 2198      |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -1.27     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -5.17e+03 |
# |    value_loss         | 3.45e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -1.02e+05 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2100      |
# |    time_elapsed       | 2308      |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -1.61     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2099      |
# |    policy_loss        | -2.2e+03  |
# |    value_loss         | 1.99e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 10800
# Best mean reward: -84515.40 - Last mean reward per episode: -101303.32
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -1e+05   |
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 2200     |
# |    time_elapsed       | 2419     |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2199     |
# |    policy_loss        | -951     |
# |    value_loss         | 2.75e+05 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -9.8e+04 |
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 2300     |
# |    time_elapsed       | 2521     |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.841   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2299     |
# |    policy_loss        | -106     |
# |    value_loss         | 6.99e+04 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.57e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2400      |
# |    time_elapsed       | 2626      |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | 1.57e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2399      |
# |    policy_loss        | -653      |
# |    value_loss         | 1.97e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.51e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2500      |
# |    time_elapsed       | 2737      |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.475    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2499      |
# |    policy_loss        | -303      |
# |    value_loss         | 1.17e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 12600
# Best mean reward: -84515.40 - Last mean reward per episode: -95559.47
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.91e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2600      |
# |    time_elapsed       | 2860      |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.391    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2599      |
# |    policy_loss        | -140      |
# |    value_loss         | 3.98e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.9e+04  |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2700      |
# |    time_elapsed       | 2966      |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -1.91     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2699      |
# |    policy_loss        | -1.41e+03 |
# |    value_loss         | 7.1e+05   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.66e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2800      |
# |    time_elapsed       | 3063      |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.47     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2799      |
# |    policy_loss        | -940      |
# |    value_loss         | 2.73e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 14400
# Best mean reward: -84515.40 - Last mean reward per episode: -95018.11
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.42e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2900      |
# |    time_elapsed       | 3159      |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2899      |
# |    policy_loss        | -2.3e+03  |
# |    value_loss         | 1.01e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.27e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3000      |
# |    time_elapsed       | 3255      |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.687    |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -216      |
# |    value_loss         | 2.18e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.09e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3100      |
# |    time_elapsed       | 3351      |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3099      |
# |    policy_loss        | -505      |
# |    value_loss         | 4.22e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.99e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3200      |
# |    time_elapsed       | 3452      |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.3      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3199      |
# |    policy_loss        | -422      |
# |    value_loss         | 2.14e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 16200
# Best mean reward: -84515.40 - Last mean reward per episode: -89331.86
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.82e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3300      |
# |    time_elapsed       | 3550      |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.52     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3299      |
# |    policy_loss        | -430      |
# |    value_loss         | 5.54e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.83e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3400      |
# |    time_elapsed       | 3665      |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3399      |
# |    policy_loss        | -1.9e+03  |
# |    value_loss         | 4.12e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.79e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3500      |
# |    time_elapsed       | 3787      |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.762    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3499      |
# |    policy_loss        | -711      |
# |    value_loss         | 6.31e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 18000
# Best mean reward: -84515.40 - Last mean reward per episode: -87250.98
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.73e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3600      |
# |    time_elapsed       | 3908      |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.766    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3599      |
# |    policy_loss        | -4.43e+03 |
# |    value_loss         | 4.6e+06   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.76e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3700      |
# |    time_elapsed       | 4035      |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3699      |
# |    policy_loss        | -837      |
# |    value_loss         | 4.8e+05   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.79e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3800      |
# |    time_elapsed       | 4170      |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.445    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.931    |
# |    value_loss         | 102       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.66e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3900      |
# |    time_elapsed       | 4286      |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.65     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3899      |
# |    policy_loss        | -1.61e+03 |
# |    value_loss         | 2.37e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 19800
# Best mean reward: -84515.40 - Last mean reward per episode: -84075.29
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.34e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4000      |
# |    time_elapsed       | 4385      |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.284    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -35.5     |
# |    value_loss         | 5.88e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.07e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4100      |
# |    time_elapsed       | 4492      |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.882    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4099      |
# |    policy_loss        | -653      |
# |    value_loss         | 3.85e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.03e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4200      |
# |    time_elapsed       | 4591      |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4199      |
# |    policy_loss        | -1.17e+03 |
# |    value_loss         | 8.73e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.19e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4300      |
# |    time_elapsed       | 4711      |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.0162   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4299      |
# |    policy_loss        | 0.0135    |
# |    value_loss         | 68.1      |
# -------------------------------------
# Num timesteps: 21600
# Best mean reward: -84075.29 - Last mean reward per episode: -81945.46
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.25e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4400      |
# |    time_elapsed       | 4812      |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4399      |
# |    policy_loss        | -2.03e+03 |
# |    value_loss         | 1.85e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.23e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4500      |
# |    time_elapsed       | 4895      |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4499      |
# |    policy_loss        | -3.6e+03  |
# |    value_loss         | 2.54e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.29e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4600      |
# |    time_elapsed       | 4981      |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4599      |
# |    policy_loss        | -871      |
# |    value_loss         | 6.41e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 23400
# Best mean reward: -81945.46 - Last mean reward per episode: -84312.77
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.41e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4700      |
# |    time_elapsed       | 5067      |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.825    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4699      |
# |    policy_loss        | -438      |
# |    value_loss         | 4.5e+05   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.57e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4800      |
# |    time_elapsed       | 5164      |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0226   |
# |    explained_variance | 4.41e-06  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4799      |
# |    policy_loss        | 0.0221    |
# |    value_loss         | 82.6      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.49e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4900      |
# |    time_elapsed       | 5262      |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.768    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4899      |
# |    policy_loss        | -4.01e+03 |
# |    value_loss         | 1.11e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.44e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5000      |
# |    time_elapsed       | 5360      |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4999      |
# |    policy_loss        | -3.22e+03 |
# |    value_loss         | 1.04e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 25200
# Best mean reward: -81945.46 - Last mean reward per episode: -85088.68
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.39e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5100      |
# |    time_elapsed       | 5453      |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.816    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5099      |
# |    policy_loss        | -2.4e+03  |
# |    value_loss         | 2.64e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.57e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5200      |
# |    time_elapsed       | 5568      |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.076    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5199      |
# |    policy_loss        | -736      |
# |    value_loss         | 1.97e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.61e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5300      |
# |    time_elapsed       | 5680      |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.581    |
# |    explained_variance | 1.08e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5299      |
# |    policy_loss        | -343      |
# |    value_loss         | 5.41e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 27000
# Best mean reward: -81945.46 - Last mean reward per episode: -84868.15
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.49e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5400      |
# |    time_elapsed       | 5786      |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.389    |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5399      |
# |    policy_loss        | -515      |
# |    value_loss         | 3.5e+07   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.72e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5500      |
# |    time_elapsed       | 5897      |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.1      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5499      |
# |    policy_loss        | -3.75e+03 |
# |    value_loss         | 1.17e+07  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.69e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5600      |
# |    time_elapsed       | 6009      |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.28     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5599      |
# |    policy_loss        | -1.57e+03 |
# |    value_loss         | 3.07e+06  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.62e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5700      |
# |    time_elapsed       | 6124      |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.0638   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5699      |
# |    policy_loss        | -3.61     |
# |    value_loss         | 2.64e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 28800
# Best mean reward: -81945.46 - Last mean reward per episode: -86874.16
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.91e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5800      |
# |    time_elapsed       | 6240      |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5799      |
# |    policy_loss        | -1.33e+04 |
# |    value_loss         | 1.67e+08  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -9.3e+04  |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5900      |
# |    time_elapsed       | 6359      |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5899      |
# |    policy_loss        | -2.24e+04 |
# |    value_loss         | 1.75e+08  |
# ...
# |    time_elapsed       | 16378     |
# |    total_timesteps    | 80500     |
# | train/                |           |
# |    entropy_loss       | -0.859    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16099     |
# |    policy_loss        | -316      |
# |    value_loss         | 6.4e+05   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 81000
# Best mean reward: -57121.30 - Last mean reward per episode: -58316.38
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.83e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16200     |
# |    time_elapsed       | 16457     |
# |    total_timesteps    | 81000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16199     |
# |    policy_loss        | -494      |
# |    value_loss         | 2.5e+05   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.93e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16300     |
# |    time_elapsed       | 16537     |
# |    total_timesteps    | 81500     |
# | train/                |           |
# |    entropy_loss       | -1.27     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16299     |
# |    policy_loss        | -539      |
# |    value_loss         | 2.28e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.94e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16400     |
# |    time_elapsed       | 16611     |
# |    total_timesteps    | 82000     |
# | train/                |           |
# |    entropy_loss       | -0.112    |
# |    explained_variance | 0.855     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16399     |
# |    policy_loss        | 0.283     |
# |    value_loss         | 282       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.88e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16500     |
# |    time_elapsed       | 16686     |
# |    total_timesteps    | 82500     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16499     |
# |    policy_loss        | -2.03e+03 |
# |    value_loss         | 3.3e+06   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 82800
# Best mean reward: -57121.30 - Last mean reward per episode: -58651.72
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.88e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16600     |
# |    time_elapsed       | 16762     |
# |    total_timesteps    | 83000     |
# | train/                |           |
# |    entropy_loss       | -0.851    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16599     |
# |    policy_loss        | -79.4     |
# |    value_loss         | 1.73e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.81e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16700     |
# |    time_elapsed       | 16836     |
# |    total_timesteps    | 83500     |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16699     |
# |    policy_loss        | -185      |
# |    value_loss         | 6.06e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.83e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16800     |
# |    time_elapsed       | 16924     |
# |    total_timesteps    | 84000     |
# | train/                |           |
# |    entropy_loss       | -0.98     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16799     |
# |    policy_loss        | -425      |
# |    value_loss         | 1.34e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.86e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 16900     |
# |    time_elapsed       | 17009     |
# |    total_timesteps    | 84500     |
# | train/                |           |
# |    entropy_loss       | -0.0418   |
# |    explained_variance | 0.895     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16899     |
# |    policy_loss        | -0.0481   |
# |    value_loss         | 93.1      |
# -------------------------------------
# Num timesteps: 84600
# Best mean reward: -57121.30 - Last mean reward per episode: -58634.82
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.92e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 17000     |
# |    time_elapsed       | 17078     |
# |    total_timesteps    | 85000     |
# | train/                |           |
# |    entropy_loss       | -1.12     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 16999     |
# |    policy_loss        | -1.14e+03 |
# |    value_loss         | 6.57e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -5.7e+04 |
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 17100    |
# |    time_elapsed       | 17146    |
# |    total_timesteps    | 85500    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 17099    |
# |    policy_loss        | -233     |
# |    value_loss         | 2.99e+05 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.66e+04 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 17200     |
# |    time_elapsed       | 17209     |
# |    total_timesteps    | 86000     |
# | train/                |           |
# |    entropy_loss       | -0.949    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17199     |
# |    policy_loss        | -1.31e+03 |
# |    value_loss         | 5.98e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 86400
# Best mean reward: -57121.30 - Last mean reward per episode: -55120.58
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.49e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17300     |
# |    time_elapsed       | 17275     |
# |    total_timesteps    | 86500     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17299     |
# |    policy_loss        | -401      |
# |    value_loss         | 1.72e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.29e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17400     |
# |    time_elapsed       | 17338     |
# |    total_timesteps    | 87000     |
# | train/                |           |
# |    entropy_loss       | -0.259    |
# |    explained_variance | -0.669    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17399     |
# |    policy_loss        | 30.3      |
# |    value_loss         | 4.28e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -5.09e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17500     |
# |    time_elapsed       | 17396     |
# |    total_timesteps    | 87500     |
# | train/                |           |
# |    entropy_loss       | -1.67     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17499     |
# |    policy_loss        | -866      |
# |    value_loss         | 3.56e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -4.83e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17600     |
# |    time_elapsed       | 17456     |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.787    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17599     |
# |    policy_loss        | -93.1     |
# |    value_loss         | 1.47e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 88200
# Best mean reward: -55120.58 - Last mean reward per episode: -47960.71
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -4.6e+04 |
# | time/                 |          |
# |    fps                | 5        |
# |    iterations         | 17700    |
# |    time_elapsed       | 17517    |
# |    total_timesteps    | 88500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 1.87e-05 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 17699    |
# |    policy_loss        | -78      |
# |    value_loss         | 8.76e+03 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -4.46e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17800     |
# |    time_elapsed       | 17579     |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.502    |
# |    explained_variance | -1.79e-06 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17799     |
# |    policy_loss        | -16.1     |
# |    value_loss         | 1.54e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -4.31e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 17900     |
# |    time_elapsed       | 17638     |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17899     |
# |    policy_loss        | -1.21e+03 |
# |    value_loss         | 8.84e+05  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 90000
# Best mean reward: -47960.71 - Last mean reward per episode: -41617.46
# Saving new best model to final_simulation\_models\reward_11\a2c\best_model
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -4.16e+04 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 18000     |
# |    time_elapsed       | 17692     |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 17999     |
# |    policy_loss        | -712      |
# |    value_loss         | 1.36e+06  |
# -------------------------------------
