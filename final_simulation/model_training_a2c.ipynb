# %%
from pathlib import Path
import os

cfd = Path(os.getcwd())
os.chdir(cfd.parent.absolute())
os.getcwd()
# Out:
# 'D:\\Study\\RMIT\\2022\\COSC2793 - Computational Machine Learning\\Assignment02\\CML-Assign2'

# %%
from final_simulation._env.real_intersection import RealIntersection8, RealIntersection9, RealIntersection10, RealIntersection11, RealIntersectionSimpleObs13
from final_simulation._sumo.simplest_intersection_simulation import SignalStates, SumoSimulation, SumoSimulationSimpleObs
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from final_simulation._env.callbacks import SaveOnBestTrainingRewardCallback
import os

# %% [markdown]
# ## Reward 08

# %%
log_dir = "final_simulation\\_models\\reward_07\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 90
number_episodes = 500

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection8(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.01)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))

# %% [markdown]
# ## Reward 10

# %%
log_dir = "final_simulation\\_models\\reward_10\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 90
number_episodes = 1000

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection10(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.001)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))

# %% [markdown]
# ## Reward 11

# %%
log_dir = "final_simulation\\_models\\reward_11\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 180
number_episodes = 500

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulation(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersection11(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MultiInputPolicy', env, verbose=1, device='auto', learning_rate=0.001)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))

# %% [markdown]
# ## Reward 13 (Simple)

# %%
log_dir = "final_simulation\\_models\\reward_13\\simple\\a2c"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 180
number_episodes = 1000

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulationSimpleObs(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersectionSimpleObs13(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MlpPolicy', env, verbose=1, device='auto', learning_rate=0.001)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -6.94e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 100       |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.84     |
# |    explained_variance | 3.3e-05   |
# |    learning_rate      | 0.001     |
# |    n_updates          | 99        |
# |    policy_loss        | -243      |
# |    value_loss         | 1.88e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -7.2e+03 |
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 200      |
# |    time_elapsed       | 239      |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 1.31e-05 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 199      |
# |    policy_loss        | -193     |
# |    value_loss         | 2.84e+04 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.38e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 300       |
# |    time_elapsed       | 372       |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.27     |
# |    explained_variance | 1.25e-06  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 299       |
# |    policy_loss        | -118      |
# |    value_loss         | 1.95e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 1800
# Best mean reward: -inf - Last mean reward per episode: -7432.70
# Saving new best model to final_simulation\_models\reward_13\simple\a2c\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.47e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 400       |
# |    time_elapsed       | 518       |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.29     |
# |    explained_variance | -5.5e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 399       |
# |    policy_loss        | -252      |
# |    value_loss         | 9.93e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.36e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 500       |
# |    time_elapsed       | 661       |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1        |
# |    explained_variance | 4.17e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 499       |
# |    policy_loss        | -314      |
# |    value_loss         | 5.98e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.46e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 600       |
# |    time_elapsed       | 808       |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.183    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 599       |
# |    policy_loss        | -3.87     |
# |    value_loss         | 2.08e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -7.5e+03 |
# | time/                 |          |
# |    fps                | 3        |
# |    iterations         | 700      |
# |    time_elapsed       | 964      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 699      |
# |    policy_loss        | -115     |
# |    value_loss         | 2.4e+04  |
# ------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 3600
# Best mean reward: -7432.70 - Last mean reward per episode: -7554.15
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.64e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 800       |
# |    time_elapsed       | 1129      |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.164    |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 799       |
# |    policy_loss        | -2.62     |
# |    value_loss         | 1.23e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.77e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 900       |
# |    time_elapsed       | 1298      |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.131    |
# |    explained_variance | 1.23e-05  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 899       |
# |    policy_loss        | -0.237    |
# |    value_loss         | 191       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.83e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1000      |
# |    time_elapsed       | 1465      |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.139    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -6.07     |
# |    value_loss         | 7.75e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 5400
# Best mean reward: -7432.70 - Last mean reward per episode: -7909.30
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.91e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1100      |
# |    time_elapsed       | 1622      |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.28     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1099      |
# |    policy_loss        | -12.6     |
# |    value_loss         | 5.08e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.94e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1200      |
# |    time_elapsed       | 1781      |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.972    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1199      |
# |    policy_loss        | -135      |
# |    value_loss         | 3.17e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.96e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1300      |
# |    time_elapsed       | 1925      |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.917    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1299      |
# |    policy_loss        | -47.5     |
# |    value_loss         | 4.87e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -8e+03   |
# | time/                 |          |
# |    fps                | 3        |
# |    iterations         | 1400     |
# |    time_elapsed       | 2070     |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.717   |
# |    explained_variance | -0.0915  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1399     |
# |    policy_loss        | 3.63     |
# |    value_loss         | 9.96     |
# ------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 7200
# Best mean reward: -7432.70 - Last mean reward per episode: -8005.85
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.01e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1500      |
# |    time_elapsed       | 2213      |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.58     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1499      |
# |    policy_loss        | -356      |
# |    value_loss         | 9.53e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.05e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1600      |
# |    time_elapsed       | 2346      |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1599      |
# |    policy_loss        | -282      |
# |    value_loss         | 5.35e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.01e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1700      |
# |    time_elapsed       | 2475      |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.979    |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1699      |
# |    policy_loss        | -133      |
# |    value_loss         | 1.15e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 9000
# Best mean reward: -7432.70 - Last mean reward per episode: -7963.48
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.96e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1800      |
# |    time_elapsed       | 2598      |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1799      |
# |    policy_loss        | -36       |
# |    value_loss         | 3.65e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.94e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 1900      |
# |    time_elapsed       | 2726      |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.558    |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.574     |
# |    value_loss         | 16.7      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.92e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2000      |
# |    time_elapsed       | 2849      |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -1.57     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -246      |
# |    value_loss         | 5.03e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.94e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2100      |
# |    time_elapsed       | 2969      |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.632    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2099      |
# |    policy_loss        | -22.8     |
# |    value_loss         | 2.75e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 10800
# Best mean reward: -7432.70 - Last mean reward per episode: -7961.15
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.96e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2200      |
# |    time_elapsed       | 3103      |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.28     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2199      |
# |    policy_loss        | -7.02     |
# |    value_loss         | 2.15e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.98e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2300      |
# |    time_elapsed       | 3246      |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.101    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2299      |
# |    policy_loss        | -0.975    |
# |    value_loss         | 4.91e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.02e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2400      |
# |    time_elapsed       | 3397      |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.138    |
# |    explained_variance | 0.00193   |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.0889   |
# |    value_loss         | 2.78e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.04e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2500      |
# |    time_elapsed       | 3539      |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.0514   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2499      |
# |    policy_loss        | -1.57     |
# |    value_loss         | 6.65e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 12600
# Best mean reward: -7432.70 - Last mean reward per episode: -8056.69
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.08e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2600      |
# |    time_elapsed       | 3682      |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.367    |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2599      |
# |    policy_loss        | -12.1     |
# |    value_loss         | 2.67e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.05e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2700      |
# |    time_elapsed       | 3809      |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.264    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2699      |
# |    policy_loss        | -5.93     |
# |    value_loss         | 1.44e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -8.03e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 2800      |
# |    time_elapsed       | 3943      |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.263    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2799      |
# |    policy_loss        | -2.93     |
# |    value_loss         | 3.63e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 14400
# Best mean reward: -7432.70 - Last mean reward per episode: -8008.56
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -8e+03   |
# | time/                 |          |
# |    fps                | 3        |
# |    iterations         | 2900     |
# |    time_elapsed       | 4081     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2899     |
# |    policy_loss        | -10.3    |
# |    value_loss         | 4.92e+04 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.96e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3000      |
# |    time_elapsed       | 4207      |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.356    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -208      |
# |    value_loss         | 3.04e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.94e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3100      |
# |    time_elapsed       | 4344      |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.537    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3099      |
# |    policy_loss        | -88.7     |
# |    value_loss         | 1.39e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.89e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3200      |
# |    time_elapsed       | 4479      |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.35     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3199      |
# |    policy_loss        | -6.03     |
# |    value_loss         | 4.41e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 16200
# Best mean reward: -7432.70 - Last mean reward per episode: -7870.10
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.84e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3300      |
# |    time_elapsed       | 4619      |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.42     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3299      |
# |    policy_loss        | -3.07     |
# |    value_loss         | 1.1e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.81e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3400      |
# |    time_elapsed       | 4757      |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.255    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3399      |
# |    policy_loss        | -8.16     |
# |    value_loss         | 3.56e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.81e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3500      |
# |    time_elapsed       | 4892      |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.0637   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3499      |
# |    policy_loss        | -1.98     |
# |    value_loss         | 6.09e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 18000
# Best mean reward: -7432.70 - Last mean reward per episode: -7830.11
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.83e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3600      |
# |    time_elapsed       | 5034      |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.124    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3599      |
# |    policy_loss        | -176      |
# |    value_loss         | 2.23e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.84e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3700      |
# |    time_elapsed       | 5169      |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.602    |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3699      |
# |    policy_loss        | -15       |
# |    value_loss         | 1.18e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.82e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3800      |
# |    time_elapsed       | 5308      |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.236    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3799      |
# |    policy_loss        | -42.2     |
# |    value_loss         | 731       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.83e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 3900      |
# |    time_elapsed       | 5452      |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.682    |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3899      |
# |    policy_loss        | -54.1     |
# |    value_loss         | 6.28e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 19800
# Best mean reward: -7432.70 - Last mean reward per episode: -7833.12
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.84e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4000      |
# |    time_elapsed       | 5586      |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0843   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.82     |
# |    value_loss         | 6.09e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.89e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4100      |
# |    time_elapsed       | 5728      |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0931   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4099      |
# |    policy_loss        | -2.17     |
# |    value_loss         | 2.82e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.91e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4200      |
# |    time_elapsed       | 5871      |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.293    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4199      |
# |    policy_loss        | -39.5     |
# |    value_loss         | 1.14e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.92e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4300      |
# |    time_elapsed       | 6019      |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.0279   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4299      |
# |    policy_loss        | 0.0257    |
# |    value_loss         | 66.2      |
# -------------------------------------
# Num timesteps: 21600
# Best mean reward: -7432.70 - Last mean reward per episode: -7920.04
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.93e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4400      |
# |    time_elapsed       | 6167      |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.193    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4399      |
# |    policy_loss        | -8.7      |
# |    value_loss         | 7.3e+04   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.93e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4500      |
# |    time_elapsed       | 6307      |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.131    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4499      |
# |    policy_loss        | -4.56     |
# |    value_loss         | 4.22e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.92e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4600      |
# |    time_elapsed       | 6449      |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.845    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4599      |
# |    policy_loss        | -94.4     |
# |    value_loss         | 2.46e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 23400
# Best mean reward: -7432.70 - Last mean reward per episode: -7902.67
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.89e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4700      |
# |    time_elapsed       | 6586      |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.477    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4699      |
# |    policy_loss        | -97.3     |
# |    value_loss         | 6.12e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.86e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4800      |
# |    time_elapsed       | 6726      |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0896   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4799      |
# |    policy_loss        | 0.109     |
# |    value_loss         | 79.9      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.85e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 4900      |
# |    time_elapsed       | 6857      |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.841    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4899      |
# |    policy_loss        | -37.9     |
# |    value_loss         | 3.74e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.83e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5000      |
# |    time_elapsed       | 6988      |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.737    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 4999      |
# |    policy_loss        | -53.7     |
# |    value_loss         | 3.28e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 25200
# Best mean reward: -7432.70 - Last mean reward per episode: -7823.36
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -7.8e+03 |
# | time/                 |          |
# |    fps                | 3        |
# |    iterations         | 5100     |
# |    time_elapsed       | 7120     |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.743   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 5099     |
# |    policy_loss        | -114     |
# |    value_loss         | 3.01e+04 |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -7.8e+03 |
# | time/                 |          |
# |    fps                | 3        |
# |    iterations         | 5200     |
# |    time_elapsed       | 7261     |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.164   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.001    |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.983   |
# |    value_loss         | 1.4e+03  |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.84e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5300      |
# |    time_elapsed       | 7409      |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.405    |
# |    explained_variance | -0.0419   |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5299      |
# |    policy_loss        | 11.4      |
# |    value_loss         | 1.25e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 27000
# Best mean reward: -7432.70 - Last mean reward per episode: -7863.28
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.86e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5400      |
# |    time_elapsed       | 7549      |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.738    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5399      |
# |    policy_loss        | -36.9     |
# |    value_loss         | 3.3e+04   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.88e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5500      |
# |    time_elapsed       | 7680      |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.271    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5499      |
# |    policy_loss        | -159      |
# |    value_loss         | 4.71e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.91e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5600      |
# |    time_elapsed       | 7817      |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.3      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5599      |
# |    policy_loss        | -6.96     |
# |    value_loss         | 1.29e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.93e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5700      |
# |    time_elapsed       | 7969      |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.41     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5699      |
# |    policy_loss        | -4.44     |
# |    value_loss         | 1.66e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 28800
# Best mean reward: -7432.70 - Last mean reward per episode: -7912.13
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.91e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5800      |
# |    time_elapsed       | 8108      |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.838    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5799      |
# |    policy_loss        | -250      |
# |    value_loss         | 6.62e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -7.91e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 5900      |
# |    time_elapsed       | 8240      |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.542    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 5899      |
# |    policy_loss        | -142      |
# |    value_loss         | 6.6e+04   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -7.9e+03 |
# | time/                 |          |
# |    fps                | 3        |
# ...
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.07e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34100     |
# |    time_elapsed       | 36241     |
# |    total_timesteps    | 170500    |
# | train/                |           |
# |    entropy_loss       | -0.353    |
# |    explained_variance | -5.69     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34099     |
# |    policy_loss        | 3.56      |
# |    value_loss         | 1.52e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 171000
# Best mean reward: -1754.24 - Last mean reward per episode: -2079.97
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.08e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34200     |
# |    time_elapsed       | 36329     |
# |    total_timesteps    | 171000    |
# | train/                |           |
# |    entropy_loss       | -0.47     |
# |    explained_variance | -0.428    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34199     |
# |    policy_loss        | -5.64     |
# |    value_loss         | 1.16e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.05e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34300     |
# |    time_elapsed       | 36404     |
# |    total_timesteps    | 171500    |
# | train/                |           |
# |    entropy_loss       | -0.378    |
# |    explained_variance | -8.99     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34299     |
# |    policy_loss        | 83        |
# |    value_loss         | 3.21e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.05e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34400     |
# |    time_elapsed       | 36478     |
# |    total_timesteps    | 172000    |
# | train/                |           |
# |    entropy_loss       | -0.602    |
# |    explained_variance | -5.32e+03 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34399     |
# |    policy_loss        | -28.9     |
# |    value_loss         | 1.61e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.03e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34500     |
# |    time_elapsed       | 36541     |
# |    total_timesteps    | 172500    |
# | train/                |           |
# |    entropy_loss       | -0.439    |
# |    explained_variance | -24.7     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34499     |
# |    policy_loss        | 11.9      |
# |    value_loss         | 673       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 172800
# Best mean reward: -1754.24 - Last mean reward per episode: -2018.25
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.02e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34600     |
# |    time_elapsed       | 36604     |
# |    total_timesteps    | 173000    |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -0.341    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34599     |
# |    policy_loss        | 5.26      |
# |    value_loss         | 71.2      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.01e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34700     |
# |    time_elapsed       | 36677     |
# |    total_timesteps    | 173500    |
# | train/                |           |
# |    entropy_loss       | -0.555    |
# |    explained_variance | -42.6     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34699     |
# |    policy_loss        | 42.6      |
# |    value_loss         | 1.83e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.01e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34800     |
# |    time_elapsed       | 36749     |
# |    total_timesteps    | 174000    |
# | train/                |           |
# |    entropy_loss       | -0.111    |
# |    explained_variance | 0.469     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34799     |
# |    policy_loss        | 0.325     |
# |    value_loss         | 231       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.02e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 34900     |
# |    time_elapsed       | 36817     |
# |    total_timesteps    | 174500    |
# | train/                |           |
# |    entropy_loss       | -0.174    |
# |    explained_variance | 0.000212  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34899     |
# |    policy_loss        | -46.4     |
# |    value_loss         | 2.87e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 174600
# Best mean reward: -1754.24 - Last mean reward per episode: -2036.38
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.04e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35000     |
# |    time_elapsed       | 36883     |
# |    total_timesteps    | 175000    |
# | train/                |           |
# |    entropy_loss       | -0.236    |
# |    explained_variance | -31.3     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 34999     |
# |    policy_loss        | 0.589     |
# |    value_loss         | 1.8e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.08e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35100     |
# |    time_elapsed       | 36962     |
# |    total_timesteps    | 175500    |
# | train/                |           |
# |    entropy_loss       | -0.39     |
# |    explained_variance | 0.000829  |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35099     |
# |    policy_loss        | 0.252     |
# |    value_loss         | 23.2      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.11e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35200     |
# |    time_elapsed       | 37041     |
# |    total_timesteps    | 176000    |
# | train/                |           |
# |    entropy_loss       | -0.457    |
# |    explained_variance | -0.489    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35199     |
# |    policy_loss        | 0.331     |
# |    value_loss         | 225       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 176400
# Best mean reward: -1754.24 - Last mean reward per episode: -2146.09
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.16e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35300     |
# |    time_elapsed       | 37117     |
# |    total_timesteps    | 176500    |
# | train/                |           |
# |    entropy_loss       | -0.11     |
# |    explained_variance | -1.6      |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35299     |
# |    policy_loss        | 10.8      |
# |    value_loss         | 1.3e+06   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.18e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35400     |
# |    time_elapsed       | 37183     |
# |    total_timesteps    | 177000    |
# | train/                |           |
# |    entropy_loss       | -0.274    |
# |    explained_variance | -0.306    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35399     |
# |    policy_loss        | -28.7     |
# |    value_loss         | 1.02e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.19e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35500     |
# |    time_elapsed       | 37250     |
# |    total_timesteps    | 177500    |
# | train/                |           |
# |    entropy_loss       | -0.438    |
# |    explained_variance | -25.8     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35499     |
# |    policy_loss        | 4.89      |
# |    value_loss         | 1.77e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.21e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35600     |
# |    time_elapsed       | 37315     |
# |    total_timesteps    | 178000    |
# | train/                |           |
# |    entropy_loss       | -0.455    |
# |    explained_variance | -8.96     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35599     |
# |    policy_loss        | -21       |
# |    value_loss         | 3.36e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 178200
# Best mean reward: -1754.24 - Last mean reward per episode: -2209.40
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -2.2e+03 |
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 35700    |
# |    time_elapsed       | 37379    |
# |    total_timesteps    | 178500   |
# | train/                |          |
# |    entropy_loss       | -0.328   |
# |    explained_variance | 0.507    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 35699    |
# |    policy_loss        | 2.62     |
# |    value_loss         | 97.4     |
# ------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.22e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35800     |
# |    time_elapsed       | 37447     |
# |    total_timesteps    | 179000    |
# | train/                |           |
# |    entropy_loss       | -0.214    |
# |    explained_variance | -3.09     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35799     |
# |    policy_loss        | -0.528    |
# |    value_loss         | 820       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.23e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 35900     |
# |    time_elapsed       | 37512     |
# |    total_timesteps    | 179500    |
# | train/                |           |
# |    entropy_loss       | -0.263    |
# |    explained_variance | -35.2     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35899     |
# |    policy_loss        | -1.13     |
# |    value_loss         | 428       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 180000
# Best mean reward: -1754.24 - Last mean reward per episode: -2257.41
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 179       |
# |    ep_rew_mean        | -2.26e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 36000     |
# |    time_elapsed       | 37577     |
# |    total_timesteps    | 180000    |
# | train/                |           |
# |    entropy_loss       | -0.0547   |
# |    explained_variance | -8.27e-05 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 35999     |
# |    policy_loss        | -0.257    |
# |    value_loss         | 520       |
# -------------------------------------

# %% [markdown]
# # Final Training
# ---

# %% [markdown]
# ### LR 0.1

# %%
log_dir = "final_simulation\\_models\\final\\a2c\\lr_0_1"
os.makedirs(log_dir, exist_ok=True)

# Sim time 1 minute
max_simulation_seconds = 120
number_episodes = 2000

# Save best check frequency
check_freq = max_simulation_seconds * 10

# %%
# Define simulation
simulation = SumoSimulationSimpleObs(
    sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo",
    #sumo_binary_path="C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo-gui",
    sumo_config_path="C:\\sumoconfig\\real_intersection.sumocfg",
    signal_states=SignalStates
)

# Define environment
env = RealIntersectionSimpleObs13(
    simulation=simulation,
    max_simulation_seconds=max_simulation_seconds
)

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=check_freq,log_dir=log_dir)

# %%
# Define agent
model = A2C('MlpPolicy', env, verbose=1, device='auto', learning_rate=0.1, gamma=0.9)
# Train the agent
model.learn(total_timesteps=int(max_simulation_seconds*number_episodes),callback=callback)
model.save("{0}\\final_model".format(log_dir))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.14e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 100       |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -4.02e-13 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 99        |
# |    policy_loss        | -0        |
# |    value_loss         | 1.31e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 200       |
# |    time_elapsed       | 181       |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -3.37e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 199       |
# |    policy_loss        | -0        |
# |    value_loss         | 1.53e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 1200
# Best mean reward: -inf - Last mean reward per episode: -4130.00
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 300       |
# |    time_elapsed       | 270       |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3.88e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 299       |
# |    policy_loss        | -0        |
# |    value_loss         | 69.4      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 400       |
# |    time_elapsed       | 360       |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 399       |
# |    policy_loss        | -0        |
# |    value_loss         | 2.4e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 2400
# Best mean reward: -4130.00 - Last mean reward per episode: -4128.00
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 500       |
# |    time_elapsed       | 456       |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 499       |
# |    policy_loss        | -0        |
# |    value_loss         | 7.3e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 600       |
# |    time_elapsed       | 548       |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -3.92e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 599       |
# |    policy_loss        | -0        |
# |    value_loss         | 1.23e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 700       |
# |    time_elapsed       | 644       |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3.39e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 699       |
# |    policy_loss        | -0        |
# |    value_loss         | 1.18e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 3600
# Best mean reward: -4128.00 - Last mean reward per episode: -4127.33
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 800       |
# |    time_elapsed       | 749       |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -3.88e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 799       |
# |    policy_loss        | -0        |
# |    value_loss         | 86.5      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 900       |
# |    time_elapsed       | 867       |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 899       |
# |    policy_loss        | -0        |
# |    value_loss         | 2.56e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 4800
# Best mean reward: -4127.33 - Last mean reward per episode: -4127.00
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 1000      |
# |    time_elapsed       | 988       |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 999       |
# |    policy_loss        | -0        |
# |    value_loss         | 7.58e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 1100      |
# |    time_elapsed       | 1099      |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -3.82e-13 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1099      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.16e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 6000
# Best mean reward: -4127.00 - Last mean reward per episode: -4126.80
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1200      |
# |    time_elapsed       | 1212      |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -3.41e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1199      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.11e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1300      |
# |    time_elapsed       | 1329      |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -3.88e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1299      |
# |    policy_loss        | -0        |
# |    value_loss         | 104       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1400      |
# |    time_elapsed       | 1444      |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1399      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.77e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 7200
# Best mean reward: -4126.80 - Last mean reward per episode: -4126.67
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1500      |
# |    time_elapsed       | 1567      |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1499      |
# |    policy_loss        | -0        |
# |    value_loss         | 7.78e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1600      |
# |    time_elapsed       | 1681      |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -3.73e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1599      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.1e+04   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 8400
# Best mean reward: -4126.67 - Last mean reward per episode: -4126.57
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1700      |
# |    time_elapsed       | 1802      |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -3.44e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1699      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.04e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1800      |
# |    time_elapsed       | 1914      |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -3.88e-13 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1799      |
# |    policy_loss        | -0        |
# |    value_loss         | 166       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 1900      |
# |    time_elapsed       | 2027      |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1899      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.59e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 9600
# Best mean reward: -4126.57 - Last mean reward per episode: -4126.50
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2000      |
# |    time_elapsed       | 2147      |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 1999      |
# |    policy_loss        | -0        |
# |    value_loss         | 8.05e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2100      |
# |    time_elapsed       | 2260      |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -3.64e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2099      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.08e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 10800
# Best mean reward: -4126.50 - Last mean reward per episode: -4126.44
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2200      |
# |    time_elapsed       | 2372      |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -3.47e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2199      |
# |    policy_loss        | -0        |
# |    value_loss         | 972       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2300      |
# |    time_elapsed       | 2488      |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2299      |
# |    policy_loss        | -0        |
# |    value_loss         | 259       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 12000
# Best mean reward: -4126.44 - Last mean reward per episode: -4126.40
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2400      |
# |    time_elapsed       | 2603      |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2399      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.75e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2500      |
# |    time_elapsed       | 2723      |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2499      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.61e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2600      |
# |    time_elapsed       | 2834      |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -3.55e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2599      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.03e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 13200
# Best mean reward: -4126.40 - Last mean reward per episode: -4126.00
# Saving new best model to final_simulation\_models\final\a2c\lr_0_1\best_model
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2700      |
# |    time_elapsed       | 2948      |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -3.49e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2699      |
# |    policy_loss        | -0        |
# |    value_loss         | 890       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2800      |
# |    time_elapsed       | 3063      |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2799      |
# |    policy_loss        | -0        |
# |    value_loss         | 350       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 14400
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 2900      |
# |    time_elapsed       | 3178      |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2899      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.85e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3000      |
# |    time_elapsed       | 3295      |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -5.55e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 2999      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.38e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3100      |
# |    time_elapsed       | 3406      |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -3.49e-13 |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3099      |
# |    policy_loss        | -0        |
# |    value_loss         | 9.45e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 15600
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3200      |
# |    time_elapsed       | 3519      |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -3.52e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3199      |
# |    policy_loss        | -0        |
# |    value_loss         | 780       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3300      |
# |    time_elapsed       | 3634      |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3299      |
# |    policy_loss        | -0        |
# |    value_loss         | 431       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 16800
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3400      |
# |    time_elapsed       | 3752      |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3399      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.91e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3500      |
# |    time_elapsed       | 3870      |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -5.96e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3499      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.97e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 18000
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3600      |
# |    time_elapsed       | 3980      |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -3.44e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3599      |
# |    policy_loss        | -0        |
# |    value_loss         | 8.2e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3700      |
# |    time_elapsed       | 4093      |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -3.56e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3699      |
# |    policy_loss        | -0        |
# |    value_loss         | 480       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3800      |
# |    time_elapsed       | 4207      |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3799      |
# |    policy_loss        | -0        |
# |    value_loss         | 365       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 19200
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 3900      |
# |    time_elapsed       | 4323      |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3899      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.15e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4000      |
# |    time_elapsed       | 4439      |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -6.38e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 3999      |
# |    policy_loss        | -0        |
# |    value_loss         | 4.28e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 20400
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4100      |
# |    time_elapsed       | 4550      |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -3.41e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4099      |
# |    policy_loss        | -0        |
# |    value_loss         | 7.01e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4200      |
# |    time_elapsed       | 4664      |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -3.59e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4199      |
# |    policy_loss        | -0        |
# |    value_loss         | 375       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4300      |
# |    time_elapsed       | 4780      |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4299      |
# |    policy_loss        | -0        |
# |    value_loss         | 404       |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 21600
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4400      |
# |    time_elapsed       | 4896      |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4399      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.39e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4500      |
# |    time_elapsed       | 5012      |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -6.8e-13  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4499      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.17e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 22800
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4600      |
# |    time_elapsed       | 5124      |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -3.39e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4599      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.82e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4700      |
# |    time_elapsed       | 5238      |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -3.63e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4699      |
# |    policy_loss        | -0        |
# |    value_loss         | 296       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 24000
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4800      |
# |    time_elapsed       | 5353      |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4799      |
# |    policy_loss        | -0        |
# |    value_loss         | 460       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 4900      |
# |    time_elapsed       | 5469      |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4899      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.62e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5000      |
# |    time_elapsed       | 5584      |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -7.2e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 4999      |
# |    policy_loss        | -0        |
# |    value_loss         | 1.41e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 25200
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5100      |
# |    time_elapsed       | 5696      |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -3.36e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 5099      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.01e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5200      |
# |    time_elapsed       | 5809      |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -3.67e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 5199      |
# |    policy_loss        | -0        |
# |    value_loss         | 227       |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 26400
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 5300      |
# |    time_elapsed       | 5924      |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 5299      |
# |    policy_loss        | -0        |
# |    value_loss         | 547       |
# -------------------------------------
# ...
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46300     |
# |    time_elapsed       | 64950     |
# |    total_timesteps    | 231500    |
# | train/                |           |
# |    entropy_loss       | -3.33e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46299     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.69e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 231600
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46400     |
# |    time_elapsed       | 65028     |
# |    total_timesteps    | 232000    |
# | train/                |           |
# |    entropy_loss       | -3.86e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46399     |
# |    policy_loss        | -0        |
# |    value_loss         | 25        |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46500     |
# |    time_elapsed       | 65107     |
# |    total_timesteps    | 232500    |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46499     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.83e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 232800
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46600     |
# |    time_elapsed       | 65187     |
# |    total_timesteps    | 233000    |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46599     |
# |    policy_loss        | -0        |
# |    value_loss         | 6.71e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46700     |
# |    time_elapsed       | 65265     |
# |    total_timesteps    | 233500    |
# | train/                |           |
# |    entropy_loss       | -4.2e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46699     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.39e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 234000
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46800     |
# |    time_elapsed       | 65342     |
# |    total_timesteps    | 234000    |
# | train/                |           |
# |    entropy_loss       | -3.34e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46799     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.54e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 46900     |
# |    time_elapsed       | 65419     |
# |    total_timesteps    | 234500    |
# | train/                |           |
# |    entropy_loss       | -3.87e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46899     |
# |    policy_loss        | -0        |
# |    value_loss         | 36.1      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47000     |
# |    time_elapsed       | 65499     |
# |    total_timesteps    | 235000    |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 46999     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.01e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 235200
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47100     |
# |    time_elapsed       | 65579     |
# |    total_timesteps    | 235500    |
# | train/                |           |
# |    entropy_loss       | -3.89e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47099     |
# |    policy_loss        | -0        |
# |    value_loss         | 7.14e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47200     |
# |    time_elapsed       | 65655     |
# |    total_timesteps    | 236000    |
# | train/                |           |
# |    entropy_loss       | -4.1e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47199     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.37e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 236400
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47300     |
# |    time_elapsed       | 65732     |
# |    total_timesteps    | 236500    |
# | train/                |           |
# |    entropy_loss       | -3.36e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47299     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.4e+03   |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47400     |
# |    time_elapsed       | 65810     |
# |    total_timesteps    | 237000    |
# | train/                |           |
# |    entropy_loss       | -3.87e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47399     |
# |    policy_loss        | -0        |
# |    value_loss         | 45.2      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47500     |
# |    time_elapsed       | 65889     |
# |    total_timesteps    | 237500    |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47499     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.19e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# Num timesteps: 237600
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47600     |
# |    time_elapsed       | 65969     |
# |    total_timesteps    | 238000    |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47599     |
# |    policy_loss        | -0        |
# |    value_loss         | 6.93e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47700     |
# |    time_elapsed       | 66045     |
# |    total_timesteps    | 238500    |
# | train/                |           |
# |    entropy_loss       | -4.02e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47699     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.32e+04  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 238800
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47800     |
# |    time_elapsed       | 66121     |
# |    total_timesteps    | 239000    |
# | train/                |           |
# |    entropy_loss       | -3.37e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47799     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.26e+03  |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 47900     |
# |    time_elapsed       | 66199     |
# |    total_timesteps    | 239500    |
# | train/                |           |
# |    entropy_loss       | -3.88e-13 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47899     |
# |    policy_loss        | -0        |
# |    value_loss         | 65.6      |
# -------------------------------------
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# saving observation file..
# No simulation running.
# Num timesteps: 240000
# Best mean reward: -4126.00 - Last mean reward per episode: -4126.00
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 119       |
# |    ep_rew_mean        | -4.13e+03 |
# | time/                 |           |
# |    fps                | 3         |
# |    iterations         | 48000     |
# |    time_elapsed       | 66279     |
# |    total_timesteps    | 240000    |
# | train/                |           |
# |    entropy_loss       | -3.9e-13  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.1       |
# |    n_updates          | 47999     |
# |    policy_loss        | -0        |
# |    value_loss         | 2.4e+03   |
# -------------------------------------
