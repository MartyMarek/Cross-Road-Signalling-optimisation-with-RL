# %%
from stable_baselines3.common import results_plotter
import numpy as np
import matplotlib.pyplot as plt


#log_dir = "_models\\dqn_rew_04"

# %%
log_dir = "_models\\a2c_rew_04"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection")
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection")
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection")

# %%
log_dir = "_models\\a2c_rew_05"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection")
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection")
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection")
