# %%
from stable_baselines3.common import results_plotter

# %% [markdown]
# # PPO
# ---

# %% [markdown]
# ### Reward 07

# %%
log_dir = "_models\\reward_07\\ppo"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "PPO. Reward Function 7. 2 Minute Simulation. LR = 0.01",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# ### Reward 08

# %%
log_dir = "_models\\reward_08\\ppo"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "PPO. Reward Function 7. 2 Minute Simulation. LR = 0.01",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# ### Reward 09

# %%
log_dir = "_models\\reward_09\\ppo"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "PPO. Reward Function 9. 2 Minute Simulation. LR = 0.1",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# # A2C
# ---

# %% [markdown]
# ### Reward 07

# %%
log_dir = "_models\\reward_07\\a2c"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "A2C. Reward Function 7. 2 Minute Simulation. LR = 0.1",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# # DQN
# ---

# %% [markdown]
# ### Reward 07

# %%
log_dir = "_models\\reward_07\\dqn"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "DQN. Reward Function 7. 2 Minute Simulation. LR = 0.1",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# ### Reward 08

# %%
log_dir = "_models\\reward_08\\dqn"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "DQN. Reward Function 7. 2 Minute Simulation. LR = 0.1",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %% [markdown]
# # Old
# ---

# %%
log_dir = "_models\\a2c_rew_04"
results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\dqn_rew_04_el_180_lr_0.0001"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\dqn_rew_05_el_180_lr_0.01"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\dqn_rew_06_el_180_lr_0.01"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\a2c_rew_06_el_180_lr_0.01"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\dqn_rew_06_el_180_lr_0.0001"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\a2c_rew_06_el_180_lr_0.1"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\a2c_rew_06_el_180_lr_0.1\\eval"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))
# Out:
# d:\Study\RMIT\2022\COSC2793 - Computational Machine Learning\Assignment02\CML-Assign2\_penv\lib\site-packages\stable_baselines3\common\results_plotter.py:94: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   plt.xlim(min_x, max_x)

# %%
log_dir = "_models\\ppo_rew_06_el_180_lr_0.1"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "PPO. Reward Function 6. 3 Minute Simulation. LR = 0.1",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))

# %%
log_dir = "_models\\ppo_rew_06_el_180_lr_0.1\\eval"
#results_plotter.plot_results([log_dir], None, results_plotter.X_TIMESTEPS, "Real Intersection",figsize=(15,5))
results_plotter.plot_results([log_dir], None, results_plotter.X_EPISODES, "Real Intersection",figsize=(15,5))
#results_plotter.plot_results([log_dir], None, results_plotter.X_WALLTIME, "Real Intersection",figsize=(15,5))
